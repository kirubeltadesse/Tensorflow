# %%
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd
from scipy import stats, integrate

# %%
# Run the code
# %matplotlib inline
import seaborn as sns
sns.set(color_codes=True)
np.random.seed(sum(map(ord, "distributions")))
x = np.random.normal(size=100)
sns.distplot(x)
plt
# Out:
# <module 'matplotlib.pyplot' from '/home/kirubel/miniconda3/envs/CSLabs/lib/python3.7/site-packages/matplotlib/pyplot.py'>
